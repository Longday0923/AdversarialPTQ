# %%
import matplotlib.pyplot as plt
import numpy as np

precision = ("Full-Precision", "8-bit", "6-bit", "4-bit")
model_acc = {
    'Clean Accuracy': (93.59, 93.45, 93.39, 89.07),
    'Clean Accuracy w/QAT': (0, 93.92, 93.46, 92.68),
    'Robustness': (21.45, 17.66, 23.78, 44.51),
    'Robustness w/QAT': (0, 24.46, 30.78, 51.33),
}

x = np.arange(len(precision))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize = (10, 6), layout='constrained')

for attribute, measurement in model_acc.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Top1 Accuracy (%)')
ax.set_title('ResNet-18 Adversarial Robustness with Model Quantization')
ax.set_xticks(x + 3 / 2 * width, precision)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 110)


plt.show()

fig.savefig("resnet.png")

# %%
import matplotlib.pyplot as plt
import numpy as np

precision = ("Full-Precision", "8-bit", "6-bit", "4-bit")
model_acc = {
    'Clean Accuracy': (93.59, 93.45, 93.39, 89.07),
    'Robustness': (21.45, 18.67, 21.58, 22.58),
    'Robustness w/QAT': (0, 25.22, 29.48, 35.73),
}

x = np.arange(len(precision))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize = (9, 6), layout='constrained')

for attribute, measurement in model_acc.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Top1 Accuracy (%)')
ax.set_title('ResNet-18 Adversarial Robustness on White-Box Quantized Model')
ax.set_xticks(x + width, precision)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 110)


plt.show()

fig.savefig("resnet_abl1.png")

# %%
precision = ("Full-Precision", "8-bit", "6-bit", "4-bit")
model_acc = {
    'Clean Accuracy': (84.92, 84.89, 84.21, 83.59),
    'Clean Accuracy w/QAT': (0, 92.34, 91.72, 92.01),
    'Robustness': (56.42, 55.93, 56.59, 56.89),
    'Robustness w/QAT': (0, 30.84, 36.38, 43.46),
}

x = np.arange(len(precision))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(figsize = (9, 6), layout='constrained')

for attribute, measurement in model_acc.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Top1 Accuracy (%)')
ax.set_title('Adversarial Trained WideResNet Robustness with Model Quantization')
ax.set_xticks(x + 3/2 * width, precision)
ax.legend(loc='upper left', ncols=4)
ax.set_ylim(0, 120)


plt.show()

fig.savefig("wideresnet_abl2.png")
